# %%
import pandas as pd

matches = pd.read_csv("matches.csv", index_col = 0)

matches["date"] = pd.to_datetime(matches["date"])

matches["venue_code"] = matches["venue"].astype("category").cat.codes 

matches["opp_code"] = matches["opponent"].astype("category").cat.codes

matches["hour"] = matches["time"].str.replace(":.+","",regex=True).astype("int")

matches["day_code"] = matches["date"].dt.dayofweek

matches["target"] = (matches["result"] == "W").astype("int")

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < '2022-01-01']

# %%
test = matches[matches["date"] > '2022-01-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)

# %%
acc
# Out:
# 0.6056701030927835

# %%
combined = pd.DataFrame(dict(actual=test["target"], prediction=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["prediction"])
# Out:
# prediction    0   1
# actual
# 0           186  47
# 1           106  49

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds)
# Out:
# 0.5104166666666666

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Manchester City")

# %%
group
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L   0   1
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W   5   0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W   5   0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W   1   0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D   0   0
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 54 2021-05-01  12:30  Premier League  Matchweek 34  Sat  Away      W   2   0
# 56 2021-05-08  17:30  Premier League  Matchweek 35  Sat  Home      L   1   2
# 57 2021-05-14  20:00  Premier League  Matchweek 36  Fri  Away      W   4   3
# 58 2021-05-18  19:00  Premier League  Matchweek 37  Tue  Away      L   2   3
# 59 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W   5   0
#
#           opponent  ...   fk  pk  pkatt  season             team venue_code  \
# 1        Tottenham  ...  1.0   0      0    2022  Manchester City          0
# 2     Norwich City  ...  1.0   0      0    2022  Manchester City          1
# 3          Arsenal  ...  0.0   0      0    2022  Manchester City          1
# 4   Leicester City  ...  0.0   0      0    2022  Manchester City          0
# 6      Southampton  ...  1.0   0      0    2022  Manchester City          1
# ..             ...  ...  ...  ..    ...     ...              ...        ...
# 54  Crystal Palace  ...  1.0   0      0    2021  Manchester City          0
# 56         Chelsea  ...  0.0   0      1    2021  Manchester City          1
# 57   Newcastle Utd  ...  1.0   0      0    2021  Manchester City          0
# 58        Brighton  ...  1.0   0      0    2021  Manchester City          0
# 59         Everton  ...  0.0   0      0    2021  Manchester City          1
#
#    opp_code hour  day_code  target
# 1        18   16         6       0
# 2        15   15         5       1
# 3         0   12         5       1
# 4        10   15         5       1
# 6        17   15         5       0
# ..      ...  ...       ...     ...
# 54        6   12         5       1
# 56        5   17         5       0
# 57       14   20         4       1
# 58        3   19         1       0
# 59        7   16         6       1
#
# [76 rows x 32 columns]

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_roling" for c in cols]

# %%
new_cols
# Out:
# ['gf_roling',
#  'ga_roling',
#  'sh_roling',
#  'sot_roling',
#  'dist_roling',
#  'fk_roling',
#  'pk_roling',
#  'pkatt_roling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 5  2020-10-17  17:30  Premier League   Matchweek 5  Sat  Home      W   1   0
# 7  2020-10-24  12:30  Premier League   Matchweek 6  Sat  Away      D   1   1
# 9  2020-10-31  12:30  Premier League   Matchweek 7  Sat  Away      W   1   0
# 11 2020-11-08  16:30  Premier League   Matchweek 8  Sun  Home      D   1   1
# 12 2020-11-21  17:30  Premier League   Matchweek 9  Sat  Away      L   0   2
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 52 2022-04-30  17:30  Premier League  Matchweek 35  Sat  Away      W   4   0
# 54 2022-05-08  16:30  Premier League  Matchweek 36  Sun  Home      W   5   0
# 55 2022-05-11  20:15  Premier League  Matchweek 33  Wed  Away      W   5   1
# 56 2022-05-15  14:00  Premier League  Matchweek 37  Sun  Away      D   2   2
# 57 2022-05-22  16:00  Premier League  Matchweek 38  Sun  Home      W   3   2
#
#          opponent  ...  day_code  target  gf_roling  ga_roling  sh_roling  \
# 5         Arsenal  ...         5       1   2.000000   2.333333  17.333333
# 7        West Ham  ...         5       0   1.333333   2.000000  17.333333
# 9   Sheffield Utd  ...         5       1   1.000000   0.666667  16.666667
# 11      Liverpool  ...         6       0   1.000000   0.333333  14.333333
# 12      Tottenham  ...         5       0   1.000000   0.666667  12.000000
# ..            ...  ...       ...     ...        ...        ...        ...
# 52   Leeds United  ...         5       1   3.333333   1.000000  16.000000
# 54  Newcastle Utd  ...         6       1   4.000000   0.333333  18.666667
# 55         Wolves  ...         2       1   4.666667   0.333333  20.000000
# 56       West Ham  ...         6       0   4.666667   0.333333  18.333333
# 57    Aston Villa  ...         6       1   4.000000   1.000000  22.000000
#
#    sot_roling dist_roling fk_roling  pk_roling  pkatt_roling
# 5    4.666667   19.700000  1.333333   0.333333      0.333333
# 7    3.666667   18.566667  0.666667   0.000000      0.000000
# 9    4.333333   18.933333  0.666667   0.000000      0.000000
# 11   6.666667   19.033333  1.000000   0.000000      0.000000
# 12   5.666667   20.000000  1.000000   0.000000      0.333333
# ..        ...         ...       ...        ...           ...
# 52   5.333333   17.466667  0.333333   0.333333      0.333333
# 54   6.000000   16.933333  0.000000   0.333333      0.333333
# 55   7.333333   15.600000  0.333333   0.333333      0.333333
# 56   6.666667   15.633333  0.333333   0.000000      0.000000
# 57   7.000000   16.433333  1.000000   0.000000      0.333333
#
# [73 rows x 40 columns]

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
# Out:
# /var/folders/84/7wck_qlx1bd65qm73114t9lh0000gn/T/ipykernel_8314/4052147919.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                                  date   time            comp         round  \
# team
# Arsenal                 6  2020-10-04  14:00  Premier League   Matchweek 4
#                         7  2020-10-17  17:30  Premier League   Matchweek 5
#                         9  2020-10-25  19:15  Premier League   Matchweek 6
#                         11 2020-11-01  16:30  Premier League   Matchweek 7
#                         13 2020-11-08  19:15  Premier League   Matchweek 8
# ...                               ...    ...             ...           ...
# Wolverhampton Wanderers 37 2022-04-30  15:00  Premier League  Matchweek 35
#                         38 2022-05-07  15:00  Premier League  Matchweek 36
#                         39 2022-05-11  20:15  Premier League  Matchweek 33
#                         40 2022-05-15  14:00  Premier League  Matchweek 37
#                         41 2022-05-22  16:00  Premier League  Matchweek 38
#
#                             day venue result  gf  ga         opponent  ...  \
# team                                                                   ...
# Arsenal                 6   Sun  Home      W   2   1    Sheffield Utd  ...
#                         7   Sat  Away      L   0   1  Manchester City  ...
#                         9   Sun  Home      L   0   1   Leicester City  ...
#                         11  Sun  Away      W   1   0   Manchester Utd  ...
#                         13  Sun  Home      L   0   3      Aston Villa  ...
# ...                         ...   ...    ...  ..  ..              ...  ...
# Wolverhampton Wanderers 37  Sat  Home      L   0   3         Brighton  ...
#                         38  Sat  Away      D   2   2          Chelsea  ...
#                         39  Wed  Home      L   1   5  Manchester City  ...
#                         40  Sun  Home      D   1   1     Norwich City  ...
#                         41  Sun  Away      L   1   3        Liverpool  ...
#
#                             day_code  target  gf_roling  ga_roling  sh_roling  \
# team
# Arsenal                 6          6       1   2.000000   1.333333   8.000000
#                         7          5       0   1.666667   1.666667   5.666667
#                         9          6       0   1.000000   1.666667   7.000000
#                         11         6       1   0.666667   1.000000   9.666667
#                         13         6       0   0.333333   0.666667   9.666667
# ...                              ...     ...        ...        ...        ...
# Wolverhampton Wanderers 37         5       0   0.666667   1.000000   8.666667
#                         38         5       0   0.000000   1.666667   8.666667
#                         39         2       0   0.666667   2.000000  11.666667
#                         40         6       0   1.000000   3.333333  10.666667
#                         41         6       0   1.333333   2.666667  12.666667
#
#                            sot_roling dist_roling fk_roling  pk_roling  \
# team
# Arsenal                 6    3.666667   14.633333  0.666667   0.000000
#                         7    3.666667   15.366667  0.000000   0.000000
#                         9    3.666667   16.566667  0.666667   0.000000
#                         11   4.000000   16.566667  1.000000   0.000000
#                         13   2.666667   19.333333  1.000000   0.333333
# ...                               ...         ...       ...        ...
# Wolverhampton Wanderers 37   3.333333   17.400000  0.000000   0.000000
#                         38   2.333333   18.633333  0.333333   0.000000
#                         39   3.000000   17.766667  0.333333   0.000000
#                         40   2.666667   17.066667  0.333333   0.000000
#                         41   3.666667   17.766667  0.333333   0.000000
#
#                             pkatt_roling
# team
# Arsenal                 6       0.000000
#                         7       0.000000
#                         9       0.000000
#                         11      0.000000
#                         13      0.333333
# ...                                  ...
# Wolverhampton Wanderers 37      0.000000
#                         38      0.000000
#                         39      0.000000
#                         40      0.000000
#                         41      0.000000
#
# [1448 rows x 40 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 6  2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home      W   2   1
# 7  2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L   0   1
# 9  2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L   0   1
# 11 2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W   1   0
# 13 2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home      L   0   3
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 37 2022-04-30  15:00  Premier League  Matchweek 35  Sat  Home      L   0   3
# 38 2022-05-07  15:00  Premier League  Matchweek 36  Sat  Away      D   2   2
# 39 2022-05-11  20:15  Premier League  Matchweek 33  Wed  Home      L   1   5
# 40 2022-05-15  14:00  Premier League  Matchweek 37  Sun  Home      D   1   1
# 41 2022-05-22  16:00  Premier League  Matchweek 38  Sun  Away      L   1   3
#
#            opponent  ...  day_code  target  gf_roling  ga_roling  sh_roling  \
# 6     Sheffield Utd  ...         6       1   2.000000   1.333333   8.000000
# 7   Manchester City  ...         5       0   1.666667   1.666667   5.666667
# 9    Leicester City  ...         6       0   1.000000   1.666667   7.000000
# 11   Manchester Utd  ...         6       1   0.666667   1.000000   9.666667
# 13      Aston Villa  ...         6       0   0.333333   0.666667   9.666667
# ..              ...  ...       ...     ...        ...        ...        ...
# 37         Brighton  ...         5       0   0.666667   1.000000   8.666667
# 38          Chelsea  ...         5       0   0.000000   1.666667   8.666667
# 39  Manchester City  ...         2       0   0.666667   2.000000  11.666667
# 40     Norwich City  ...         6       0   1.000000   3.333333  10.666667
# 41        Liverpool  ...         6       0   1.333333   2.666667  12.666667
#
#    sot_roling dist_roling fk_roling  pk_roling  pkatt_roling
# 6    3.666667   14.633333  0.666667   0.000000      0.000000
# 7    3.666667   15.366667  0.000000   0.000000      0.000000
# 9    3.666667   16.566667  0.666667   0.000000      0.000000
# 11   4.000000   16.566667  1.000000   0.000000      0.000000
# 13   2.666667   19.333333  1.000000   0.333333      0.333333
# ..        ...         ...       ...        ...           ...
# 37   3.333333   17.400000  0.000000   0.000000      0.000000
# 38   2.333333   18.633333  0.333333   0.000000      0.000000
# 39   3.000000   17.766667  0.333333   0.000000      0.000000
# 40   2.666667   17.066667  0.333333   0.000000      0.000000
# 41   3.666667   17.766667  0.333333   0.000000      0.000000
#
# [1448 rows x 40 columns]

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
matches_rolling
# Out:
#            date   time            comp         round  day venue result  gf  \
# 0    2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home      W   2
# 1    2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L   0
# 2    2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L   0
# 3    2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W   1
# 4    2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home      L   0
# ...         ...    ...             ...           ...  ...   ...    ...  ..
# 1443 2022-04-30  15:00  Premier League  Matchweek 35  Sat  Home      L   0
# 1444 2022-05-07  15:00  Premier League  Matchweek 36  Sat  Away      D   2
# 1445 2022-05-11  20:15  Premier League  Matchweek 33  Wed  Home      L   1
# 1446 2022-05-15  14:00  Premier League  Matchweek 37  Sun  Home      D   1
# 1447 2022-05-22  16:00  Premier League  Matchweek 38  Sun  Away      L   1
#
#       ga         opponent  ...  day_code  target  gf_roling  ga_roling  \
# 0      1    Sheffield Utd  ...         6       1   2.000000   1.333333
# 1      1  Manchester City  ...         5       0   1.666667   1.666667
# 2      1   Leicester City  ...         6       0   1.000000   1.666667
# 3      0   Manchester Utd  ...         6       1   0.666667   1.000000
# 4      3      Aston Villa  ...         6       0   0.333333   0.666667
# ...   ..              ...  ...       ...     ...        ...        ...
# 1443   3         Brighton  ...         5       0   0.666667   1.000000
# 1444   2          Chelsea  ...         5       0   0.000000   1.666667
# 1445   5  Manchester City  ...         2       0   0.666667   2.000000
# 1446   1     Norwich City  ...         6       0   1.000000   3.333333
# 1447   3        Liverpool  ...         6       0   1.333333   2.666667
#
#       sh_roling sot_roling dist_roling fk_roling  pk_roling  pkatt_roling
# 0      8.000000   3.666667   14.633333  0.666667   0.000000      0.000000
# 1      5.666667   3.666667   15.366667  0.000000   0.000000      0.000000
# 2      7.000000   3.666667   16.566667  0.666667   0.000000      0.000000
# 3      9.666667   4.000000   16.566667  1.000000   0.000000      0.000000
# 4      9.666667   2.666667   19.333333  1.000000   0.333333      0.333333
# ...         ...        ...         ...       ...        ...           ...
# 1443   8.666667   3.333333   17.400000  0.000000   0.000000      0.000000
# 1444   8.666667   2.333333   18.633333  0.333333   0.000000      0.000000
# 1445  11.666667   3.000000   17.766667  0.333333   0.000000      0.000000
# 1446  10.666667   2.666667   17.066667  0.333333   0.000000      0.000000
# 1447  12.666667   3.666667   17.766667  0.333333   0.000000      0.000000
#
# [1448 rows x 40 columns]

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2022-01-01']
    test = data[data["date"] > '2022-01-01']
    rf.fit(train[predictors], train["target"])
    pred = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    precision = precision_score(test["target"], preds)
    return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.4375

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
combined
# Out:
#       actual  predicted       date                     team         opponent  \
# 55         0          0 2022-01-23                  Arsenal          Burnley
# 56         1          0 2022-02-10                  Arsenal           Wolves
# 57         1          0 2022-02-19                  Arsenal        Brentford
# 58         1          1 2022-02-24                  Arsenal           Wolves
# 59         1          1 2022-03-06                  Arsenal          Watford
# ...      ...        ...        ...                      ...              ...
# 1443       0          0 2022-04-30  Wolverhampton Wanderers         Brighton
# 1444       0          0 2022-05-07  Wolverhampton Wanderers          Chelsea
# 1445       0          0 2022-05-11  Wolverhampton Wanderers  Manchester City
# 1446       0          0 2022-05-15  Wolverhampton Wanderers     Norwich City
# 1447       0          0 2022-05-22  Wolverhampton Wanderers        Liverpool
#
#      result
# 55        D
# 56        W
# 57        W
# 58        W
# 59        W
# ...     ...
# 1443      L
# 1444      D
# 1445      L
# 1446      D
# 1447      L
#
# [388 rows x 6 columns]

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key 

map_values = {
    "Brighton and Hove Albion": "Brighton",
    "Manchester United": "Manuchest Utd",
    "Newcastle United": "Newcastle Utd",
    "Totthenham Hotspur": "Tottenham",
    "West Ham United": "West Ham",
    "Wolverhampton Wanderers": "Wolves"
}

mapping = MissingDict(**map_values)

# %%
mapping["West Ham United"]
# Out:
# 'West Ham'

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] == 0)]["actual_x"].value_counts()
# Out:
# actual_x
# 0    40
# 1    28
# Name: count, dtype: int64

# %%
matches.columns
# Out:
# Index(['date', 'time', 'comp', 'round', 'day', 'venue', 'result', 'gf', 'ga',
#        'opponent', 'xg', 'xga', 'poss', 'attendance', 'captain', 'formation',
#        'referee', 'match report', 'notes', 'sh', 'sot', 'dist', 'fk', 'pk',
#        'pkatt', 'season', 'team', 'venue_code', 'opp_code', 'hour', 'day_code',
#        'target'],
#       dtype='object')
